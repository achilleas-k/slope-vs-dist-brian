# %%
import spikerlib as sl
kreuz = sl.metrics.kreuz.multivariate

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def gen_spiketrains(N, f, Sin, sigma, duration):
    N_sync = int(N*Sin)
    N_rand = N-N_sync
    spikearray = empty(N, dtype=object)
    for trainidx in range(0, N_rand):
        spikearray[trainidx] = sl.tools.poisson_times(f, duration)
    if N_sync:
        synctrain = sl.tools.poisson_times(f, duration)
        for trainidx in range(N_rand, N):
            spikearray[trainidx] = copy(synctrain)
            if sigma:
                jitter = random.normal(0, sigma, len(synctrain))
                spikearray[trainidx] += jitter
    return spikearray

# %% [markdown]
# - - -
# # All random

# %%
N = 500
inrate = 10
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 9.9304 Hz
# SPIKE-distance: 2.39976644055

# %% [markdown]
# - - -
# # Half synchrony

# %%
N = 500
inrate = 10
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.5, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 10.662 Hz
# SPIKE-distance: 2.26210017696

# %% [markdown]
# - - -
# # Higher synchrony

# %%
N = 500
inrate = 10
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 10.3168 Hz
# SPIKE-distance: 1.77248571184

# %%
N = 10
inrate = 10
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 9.46 Hz
# SPIKE-distance: 0.890402875358

# %% [markdown]
# - - -
# # Cases from paper

# %%
N = 200
inrate = 50
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 50.606 Hz
# SPIKE-distance: 1.718154388

# %%
N = 50
inrate = 50
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 48.572 Hz
# SPIKE-distance: 1.64014725046

# %%
N = 10
inrate = 50
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 49.26 Hz
# SPIKE-distance: 1.20221605065

# %%
N = 300
inrate = 50
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 47.446 Hz
# SPIKE-distance: 1.70406497579

# %%
N = 400
inrate = 50
duration = 5.0
spiketrains = gen_spiketrains(N, inrate, 0.8, 0, duration)
figure()
for h, sp in enumerate(spiketrains):
    plot(sp, zeros_like(sp)+h, 'b.')
xlabel("t")
ylabel("id#")
print("Mean rate: {} Hz".format(mean([len(st) for st in spiketrains])/duration))
dt = 0.001
samples = duration/dt
krt, krd = kreuz(spiketrains, 0, duration, samples)
print("SPIKE-distance: {}".format(trapz(krd, krt)))
# Out:
# Mean rate: 47.8945 Hz
# SPIKE-distance: 1.7001630139
